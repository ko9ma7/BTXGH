# %%
#### Importing Required Modules

from bs4 import BeautifulSoup as bs
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import requests
import lxml
import pandas as pd

# %%
#### Webdriver options setting

options = webdriver.ChromeOptions()

options.add_argument('headless')

options.add_argument('window-size=1920x1080')

path = 'chromedriver.exe'
driver = webdriver.Chrome(path, options=options)
driver.implicitly_wait(3)

# %%
#### Save Data in dict

posts = {'post_id' : [],
'제목' : [],
'글쓴이' : [],
'작성일' : [],
'조회수' : [],
'추천수' : [],
}

# %%
#### Crawl over posts pages

epoch = 90

url = "https://gall.dcinside.com/board/lists/?id=cosmetic&page="

for i in range(1, epoch+1):

    driver.get(url+str(i))

    driver.implicitly_wait(4)

    page_html = driver.page_source

    html_parsed = bs(page_html, 'html.parser')

    #### Main table where postings are displayed

    table = html_parsed.find("tbody")

    #### Each post

    lists = table.find_all("tr")


    #### Add to Dict

    for post in lists:
        title_id = post.find("td").text
        posts['post_id'].append(title_id.strip())
        posts['제목'].append(post.find("td").find_next_sibling("td").text.strip())
        posts['글쓴이'].append(post.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
        posts['작성일'].append(post.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
        posts['조회수'].append(post.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
        posts['추천수'].append(post.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())

# %%
postings = pd.DataFrame(posts)
postings.head()
# Out:
#   post_id                                      제목    글쓴이       작성일    조회수  추천수
# 0      설문             '돈많으면 형' 형이라 부르고픈 영앤리치 스타는?    운영자  19.07.02      -    -
# 1      공지  향수 화장품 갤러리 공지-클렌저, 토너, 보습제, 기타제품\n[40]  ✨변백현✨  18.05.08  32574  104
# 2      공지       향수 화장품 갤러리 공지-2 기타제품,자외선차단제\n[46]  ✨변백현✨  18.05.08  18298   69
# 3      공지            ❥❥❥❥❥❥꿀피부가 되는 방법. ver①\n[18]   .이지은  18.01.16  32740   39
# 4      공지            ❥❥❥❥❥❥꿀피부가 되는 방법. ver②\n[19]   .이지은  18.01.16  33418   20

# %%
postings.shape
# Out:
# (4590, 6)

# %%
postings.tail(7)
# Out:
#       post_id                                   제목              글쓴이    작성일  \
# 4583  1282048  모낭염으로 씹창난곳에 염증죽고나서 마데카솔 바르니 치유력 개좋음        ㅇㅇ(1.217)  05.31
# 4584  1282047       병풀추출물 50,000ppm이면 몇% 인거지?\n[2]         ㅇㅇ(59.5)  05.31
# 4585  1282046        시발 자차 정량바르고 무심코 지하철거울봤는데\n[1]       ㅇㅇ(223.39)  05.31
# 4586  1282045          무기자차 썬크림 바르면 이중세안 해야함?\n[1]     1234(115.22)  05.31
# 4587  1282044         아넷사 안지워진대서 1년째 클오+폼 쓰는중\n[7]  1111ㅂ11(223.62)  05.31
# 4588  1282043               디페린45g  4만원에 살사람?\n[3]      ㅇㅇ(112.220)  05.31
# 4589  1282042               무기나 비비 지울때 클오vs클워\n[1]      ㅇㅇ(175.223)  05.31
#
#       조회수 추천수
# 4583  127   0
# 4584   77   0
# 4585   75   1
# 4586  170   0
# 4587  148   1
# 4588  177   0
# 4589   67   0

# %%
df = pd.read_csv("DCinside_cosmetics.csv")
df.head()
# Out:
#   post_id                                      제목    글쓴이       작성일    조회수  추천수
# 0      설문             '돈많으면 형' 형이라 부르고픈 영앤리치 스타는?    운영자  19.07.02      -    -
# 1      공지  향수 화장품 갤러리 공지-클렌저, 토너, 보습제, 기타제품\n[40]  ✨변백현✨  18.05.08  32575  104
# 2      공지       향수 화장품 갤러리 공지-2 기타제품,자외선차단제\n[46]  ✨변백현✨  18.05.08  18298   69
# 3      공지            ❥❥❥❥❥❥꿀피부가 되는 방법. ver①\n[18]   .이지은  18.01.16  32740   39
# 4      공지            ❥❥❥❥❥❥꿀피부가 되는 방법. ver②\n[19]   .이지은  18.01.16  33418   20

# %%
df.shape
# Out:
# (4590, 6)

# %%
df.iloc[30:40]
# Out:
#     post_id                              제목          글쓴이    작성일 조회수 추천수
# 30  1287614  레틴a 왜 섞발하나 했는데 발림성이 쓰레기구나\n[5]   ㅇㅇ(220.74)  07.03  58   0
# 31  1287613         훈돌아 너 ahc 선스틱 써봣어?\n[6]          짱지은  07.03  31   0
# 32  1287612          향갤최대반전) 익익이 쟤 여자임\n[3]  ㅇㅇ(175.223)  07.03  46   5
# 33  1287611          본인 군터지 쓰는데  ㄱㅊ아!!\n[2]          형식이  07.03  42   0
# 34  1287610             아넷사 올영에 가면 있냐?\n[2]   ㅇㅇ(58.238)  07.03  25   0
# 35  1287609          야 훈돌아 선크림이름 찾음ㅋㅋㅋ\n[2]  ㅇㅇ(125.132)  07.03  32   0
# 36  1287608                  휴 나는그냥 캄자차 쓰려구  ㅇㅇ(175.223)  07.03   9   0
# 37  1287607             그냥 닥터지 그린마일드 살까...?           훈돌  07.03  11   0
# 38  1287606               Pdt 해본사람있냐 이거 아파?  ㅇㅇ(125.132)  07.03   9   0
# 39  1287603      올영에서 파는 선크림 괜찮은거 추천좀\n[10]           훈돌  07.03  58   0
