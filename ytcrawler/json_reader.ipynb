# %%
import boto3
import json

# %%
cmt = []
for line in open('POWER_MOVIE.json', 'r', encoding='UTF8'): 
    cmt.append(json.loads(line))

# %%
len(cmt[0])
# Out:
# 3

# %%
cmt[0][2]
# Out:
# ['2ikFUvVxp2o',
#  {'cid': 'UgxcTUi94XiYyAtqlUN4AaABAg',
#   'text': 'Secret video - https://youtu.be/NXGYT9In4-M',
#   'time': '2주 전',
#   'author': 'POWER MOVIE'},
#  {'cid': 'UgxcTUi94XiYyAtqlUN4AaABAg.8wlfvhMzee78wsnbqoESNT',
#   'text': '1편끝나고리셋되려나',
#   'time': '1주 전',
#   'author': '장식왕샌즈'},
#  {'cid': 'UgxcTUi94XiYyAtqlUN4AaABAg.8wlfvhMzee78wnHL0FyC9U',
#   'text': 'POWER MOVIE 음.. 제발\n1주일마다 한번씩 유튜브에 공개되는 모습을 보면\n너무 시간이 길다고 생각하는데 ㅠㅠ 좀 빨리 영상\n좀 올려주세요 부탁드립니다',
#   'time': '2주 전',
#   'author': '애플'},
#  {'cid': 'UgxcTUi94XiYyAtqlUN4AaABAg.8wlfvhMzee78wmYb-oK2JV',
#   'text': '화령이님 요새  어디가심',
#   'time': '2주 전(수정됨)',
#   'author': '_아기숭이'},
#  {'cid': 'UgxcTUi94XiYyAtqlUN4AaABAg.8wlfvhMzee78wmMHG1jW0A',
#   'text': '갑분사(망플래그)',
#   'time': '2주 전',
#   'author': 'f블랙레드'},
#  {'cid': 'UgxcTUi94XiYyAtqlUN4AaABAg.8wlfvhMzee78wlw70VM6bl',
#   'text': '헐',
#   'time': '2주 전',
#   'author': '김Kim Tae Hyun'},
#  {'cid': 'UgxcTUi94XiYyAtqlUN4AaABAg.8wlfvhMzee78wlh1XwJK9S',
# ...

# %%
len(cmt[0])
# Out:
# 80

# %%
for line in open('조효진_Hyojin1.json', 'r', encoding='UTF8'): 
    cmt.append(json.loads(line))

# %%
len(cmt)
# Out:
# 21

# %%
cmt
# Out:
# [{'cid': 'UgwWy9UA3rJItrZmZrx4AaABAg',
#   'text': '효진쓰 만개웃음 처음보는것,,,미소도 예뿌자나,,?♥️',
#   'time': '3분 전',
#   'author': '베령 bell__0'},
#  {'cid': 'UgxXHAD9QJX8rp285QJ4AaABAg',
#   'text': '영상에 나온 김미연이 무슨 뜻인가요?ㅠㅠ',
#   'time': '28분 전',
#   'author': '찹쌀떡'},
#  {'cid': 'UgxgS06HuSdZQJ8QJ4R4AaABAg',
#   'text': '예뻐요ㅎㅎ',
#   'time': '32분 전',
#   'author': '연대언니'},
#  {'cid': 'UgygELuSO-P48rvt6Dl4AaABAg',
#   'text': '썸넬 원래 화장이미지가 좀 쎄더 싶은디 그게 아니고 언니 깨발랄한 꺄르르한 모습이 찍힌거같아서 넘나 새롭고 이뿌리해요',
#   'time': '57분 전',
#   'author': '김지구는 둥글어'},
#  {'cid': 'UgyxOKdsJUyQmCJYnKp4AaABAg',
#   'text': '효진님!! 혹시 일주일 전 쯤에 올리신 쨔미쓰+조파파님+복덩이 다 나오는 그 브이로그 영상 내리셨나요?? 다시 보려고 하는데 없어서요ㅠㅠ 제가 못 찾는 걸까요ㅠㅠ',
#   'time': '1시간 전',
#   'author': '이나은'},
#  {'cid': 'UgyA_yT2oQsI6m3Z30V4AaABAg',
#   'text': '영상 중간중간에 마이크 상태?가 계속 달라지는것 같아서 영상에 집중이 안돼요ㅠㅠ 그 점이 아쉬워요!! 항상 너무너무 잘 보고 있습니다♥',
#   'time': '1시간 전',
#   'author': '이현승'},
#  {'cid': 'UgzpRDLfJzU6ZwnGEeV4AaABAg',
#   'text': '세상에나... 뒤집어지게 예쁘네♡',
#   'time': '1시간 전',
# ...

# %%
json_string = json.dumps(cmt)

# %%
json_string
# Out:
# '[{"cid": "UgwWy9UA3rJItrZmZrx4AaABAg", "text": "\\ud6a8\\uc9c4\\uc4f0 \\ub9cc\\uac1c\\uc6c3\\uc74c \\ucc98\\uc74c\\ubcf4\\ub294\\uac83,,,\\ubbf8\\uc18c\\ub3c4 \\uc608\\ubfcc\\uc790\\ub098,,?\\u2665\\ufe0f", "time": "3\\ubd84 \\uc804", "author": "\\ubca0\\ub839 bell__0"}, {"cid": "UgxXHAD9QJX8rp285QJ4AaABAg", "text": "\\uc601\\uc0c1\\uc5d0 \\ub098\\uc628 \\uae40\\ubbf8\\uc5f0\\uc774 \\ubb34\\uc2a8 \\ub73b\\uc778\\uac00\\uc694?\\u3160\\u3160", "time": "28\\ubd84 \\uc804", "author": "\\ucc39\\uc300\\ub5a1"}, {"cid": "UgxgS06HuSdZQJ8QJ4R4AaABAg", "text": "\\uc608\\ubed0\\uc694\\u314e\\u314e", "time": "32\\ubd84 \\uc804", "author": "\\uc5f0\\ub300\\uc5b8\\ub2c8"}, {"cid": "UgygELuSO-P48rvt6Dl4AaABAg", "text": "\\uc378\\ub12c \\uc6d0\\ub798 \\ud654\\uc7a5\\uc774\\ubbf8\\uc9c0\\uac00 \\uc880 \\uc384\\ub354 \\uc2f6\\uc740\\ub514 \\uadf8\\uac8c \\uc544\\ub2c8\\uace0 \\uc5b8\\ub2c8 \\uae68\\ubc1c\\ub784\\ud55c \\uae84\\ub974\\ub974\\ud55c \\ubaa8\\uc2b5\\uc774 \\ucc0d\\ud78c\\uac70\\uac19\\uc
# ...

# %%
 os.system("python downloader.py --youtubeid BxfZwbG4t3A --output %s%s.json --limit 20" %(vid_list[j],youtuber_name,str(j)))
